# %%
import pandas as pd
from glob import glob
import numpy as np

# %%
files = glob("/kaggle/input/openstax-eda/*.pq")

# %%
samples = np.random.choice(files, 5)

# %%
for sample in samples:
    display(pd.read_parquet(sample).fillna(False))
# Out:
#       Chapter                                               text  is_question
# 0     Preface   The philosophy of utilitarianism is used to e...         True
# 1     Preface   Human rights include an individual’s right to...         True
# 2     Preface   The distributive process by which the burdens...         True
# 3     Preface   Ethical decision making begins in the marketi...         True
# 4     Preface   Ethics training programs typically teach how ...         True
# ...       ...                                                ...          ...
# 1525       17   List the four layers of the pyramid of social...         True
# 1526       17   According to Peter Drucker, what are the basi...         True
# 1527       17   What collective term would be used to describ...         True
# 1528       17                          What is social investing?         True
# 1529       17   How does strategic giving differ from corpora...         True
#
# [1530 rows x 3 columns]
# ...
